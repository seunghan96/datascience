# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('bank-full.csv')

# %%
plt.title('Deposit (X) Education')
no['education'].value_counts().plot(kind='pie')

# %%
plt.title('Deposit (O) Education')
yes['education'].value_counts().plot(kind='pie')

# %%
no = data[data.y=='no']
yes = data[data.y=='yes']

# %%
sns.distplot(no['age'])
sns.distplot(yes['age'])

# %%
no['default'].value_counts()
# Out:
# no     39159
# yes      763
# Name: default, dtype: int64

# %%
yes['default'].value_counts()
# Out:
# no     5237
# yes      52
# Name: default, dtype: int64
